# %% [markdown]
# ## Q1.

# %% [markdown]
# This encoding technique appears almost similar to Label Encoding. But, label encoding would not consider whether a variable is ordinal or not, but in the case of ordinal encoding, it will assign a sequence of numerical values as per the order of data.

# %% [markdown]
# ## Q2.

# %% [markdown]
# There are specifically two types of guided encoding techniques for categorical features, namely – target guided ordinal encoding & mean guided ordinal encoding.

# %% [markdown]
# ## Q3.

# %% [markdown]
# Covariance is a statistical tool used to determine the relationship between the movements of two random variables. When two stocks tend to move together, they are seen as having a positive covariance; when they move inversely, the covariance is negative.

# %% [markdown]
# ## Q4.

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Color': ('red', 'green', 'blue'),'Size': ('small', 'medium',
'large'), 'Material': ('wood', 'metal', 'plastic')})

# %%
df
# Out:
#    Color    Size Material
# 0    red   small     wood
# 1  green  medium    metal
# 2   blue   large  plastic

# %%
## label encoding for color . for material and size its better to used ordinal.

# %%
from sklearn.preprocessing import LabelEncoder

lbl_encoder=LabelEncoder()

encoded = lbl_encoder.fit_transform(df[['Color']]) ## one feature at a time . 

encoder_df=pd.DataFrame(encoded,columns=['color_label'])
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
encoder_df
# Out:
#    color_label
# 0            2
# 1            1
# 2            0

# %%
## now for material and size .

# %%
## ORdinal Encoding
from sklearn.preprocessing import OrdinalEncoder

## create an instance of ORdinalEncoder and then fit_transform
encoder=OrdinalEncoder(categories=[['small','medium','large']])

encoded = encoder.fit_transform(df[['Size']])

encoder_df_2=pd.DataFrame(encoded,columns=['Size_ordinal'])

# %%
from sklearn.preprocessing import OrdinalEncoder

## create an instance of ORdinalEncoder and then fit_transform
encoder=OrdinalEncoder(categories=[['plastic','wood','metal']])

encoded = encoder.fit_transform(df[['Material']])

encoder_df_3=pd.DataFrame(encoded,columns=['Material_ordinal'])

# %%
pd.concat([df,encoder_df,encoder_df_2,encoder_df_3],axis=1)
# Out:
#    Color    Size Material  color_label  Size_ordinal  Material_ordinal
# 0    red   small     wood            2           0.0               1.0
# 1  green  medium    metal            1           1.0               2.0
# 2   blue   large  plastic            0           2.0               0.0

# %% [markdown]
# ## Q5.

# %% [markdown]
# Step 1: Find the mean of one variable (X). ...
# Step 2: Subtract the mean from all observations; (92 - 84), (60 - 84), (100 - 84)
# Step 3: Take the sum of the squares of the differences obtained in the previous step.

# %% [markdown]
# ## 6.

# %% [markdown]
# 1. Gender - OHE
# 2. "Education Level" - Ordinal
# 3. "Employment Status" - Ordinal

# %% [markdown]
# ## 7.

# %%
df = pd.read_excel('marks.xlsx')

# %%
df
# Out:
#                 Station.Location Station.State  Data.Temperature.Avg Temp  \
# 0               Station.Location       Alabama                         39
# 1                 Huntsville, AL       Alabama                         39
# 2                     Mobile, AL       Alabama                         46
# 3                 Montgomery, AL       Alabama                         45
# 4                  Anchorage, AK        Alaska                         34
# 5                    Annette, AK        Alaska                         38
# 6                     Bethel, AK        Alaska                         30
# 7                    Bettles, AK        Alaska                         22
# 8                   Cold Bay, AK        Alaska                         34
# 9                    Cordova, AK        Alaska                         38
# 10  Delta Junction/Ft Greely, AK        Alaska                         31
# 11                 Fairbanks, AK        Alaska                         14
# ...

# %%
df.cov()
# Out:
# /tmp/ipykernel_77/1545644723.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                            Data.Temperature.Avg Temp  \
# Data.Temperature.Avg Temp                  58.362573
# Data.Temperature.Max Temp                  41.049708
# Data.Temperature.Min Temp                  70.456140
# Data.Wind.Direction                        49.979532
# Data.Wind.Speed                            11.070380
#
#                            Data.Temperature.Max Temp  \
# Data.Temperature.Avg Temp                  41.049708
# Data.Temperature.Max Temp                  34.801170
# Data.Temperature.Min Temp                  45.786550
# Data.Wind.Direction                        46.470760
# Data.Wind.Speed                             1.681257
#
# ...
