# %% [markdown]
# ## Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# ### Note: Here Exception class refers to the base class for all the exceptions.

# %% [markdown]
# Ans -The class __Exception__ and its subclasses are a form of Throwable that indicates conditions that a reasonable application might want to catch. The class Exception and any subclasses that are not also subclasses of RuntimeException are checked exceptions.
#
# In python only __Exception__ class has the liberty to handle error . So if we use out custom class . we will have to inherit the __Exception__ class

# %% [markdown]
# ## Q2. Write a python program to print Python Exception Hierarchy.

# %%
# import inspect module
import inspect

# our treeClass function
def Hierarchy(cls, ind = 0):
	
	# print name of the class
	print ('-' * ind, cls.__name__)
	
	# iterating through subclasses
	for i in cls.__subclasses__():
		Hierarchy(i, ind + 3)

print("Hierarchy for Built-in exceptions is : ")

# inspect.getmro() Return a tuple
# of class cls’s base classes.

# building a tree hierarchy
inspect.getclasstree(inspect.getmro(BaseException))

# function call
Hierarchy(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- herror
# --------- gaierror
# --------- timeout
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %% [markdown]
# ## Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The arithmetic error occurs when an error is encountered during numeric calculations in Python. This includes Zerodivision Error and Floating point error. In addition, zero division error is raised when you divide a numeric value by zero. When we run this code, we will get a ZeroDivision error.
#
# ArithmeticError types in Python include:
#
# 1. OverFlowError
# 2. ZeroDivisionError
# 3. FloatingPointError

# %%
a = 5/0
print(a) ## ZeroDivisionError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26016\2361930616.py in <module>
# ----> 1 a = 5/0
#       2 print(a)
#
# ZeroDivisionError: division by zero

# %%
0.1+0.2 ## FloatingPointError
# Out:
# 0.30000000000000004

# %% [markdown]
# ## Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively.
#
# You can use LookupError exception class to handle both IndexError and KeyError exception classes.

# %%
x = [1, 2, 3, 4]
try:
    print(x[10])
except LookupError as e:
    print(f"{e}, {e.__class__}")
# Out:
# list index out of range, <class 'IndexError'>

# %% [markdown]
# ## Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# Python's ImportError ( ModuleNotFoundError ) indicates that you tried to import a module that Python doesn't find.

# %%
import adrik
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26016\78312132.py in <module>
# ----> 1 import adrik
#
# ModuleNotFoundError: No module named 'adrik'

# %% [markdown]
# ## Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1. Catch multiple exceptions in one except block
# 2. Make use of __finally__ clause
# 3. Use the __as__ keyword to catch specific exception types
# 4. Design classes so that exceptions can be avoided
# 5. Throw exceptions instead of returning an error code.
